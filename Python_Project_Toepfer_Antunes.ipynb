# %% [markdown]
# <p style="text-align: center; font-size: 200%; text-decoration: underline"> WAM69 - Python Project </p>

# %% [markdown]
# <p style="text-align: center; font-size: 300%"> Effects of the COVID-19-Pandemic </p>
# <p style="text-align: center; font-size: 300%"> on the Swiss Public Rail Transportation </p>
# <p style="text-align: center; font-size: 300%"> </p>
# <p style="text-align: center; font-size: 200%"> Cristiano André Antunes </p>
# <p style="text-align: center; font-size: 200%"> Silvan Veit Toepfer </p>

# %% [markdown]
# # Introduction
#
# The COVID-19 pandemic affected the world in many negative ways, due to the health hazards and major lockdowns imposed by governments. The resulted supply and demand shocks led to an overall serious economic situation.
# This also impacted the public transportation industry in Switzerland as soon as restrictions were put in place. Since the general public transportation industry operates with non-storable tradeable services, an L-shaped growth regression was predicted by Baldwin and Weder di Mauro (2020) at the early stages of the pandemic. Figure 1 proves said prediction by broadcasting a major drop in rail passengers at the beginning of the COVID-19 pandemic in Switzerland.

# %% [markdown]
# #### Figure 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel ('Data/CH_rail_passenger_yearly data since 2011.xlsx')
print(data)

x = list(data['Year'])
y = list(data['Rail Passengers'])

plt.rcParams["figure.figsize"] = [10, 6]
plt.rcParams["figure.autolayout"] = True
plt.plot (x, y, 'r-')
plt.xlabel ('$Year$')
plt.ylabel ('Rail Passengers')
plt.title ('Yearly Rail Passengers in Switzerland, 2011 - 2021')
plt.legend (['$Switzerland$'])
plt.xticks(x)
plt.grid(axis="y")
plt.show()
# Out:
#     Year  Rail Passengers
# 0   2011           408580
# 1   2012           412272
# 2   2013           432462
# 3   2014           458715
# 4   2015           475183
# 5   2016           497735
# 6   2017           500595
# 7   2018           493053
# 8   2019           519337
# 9   2020           322847
# 10  2021           345997

# %% [markdown]
# *Source: [Eurostat](https://ec.europa.eu/eurostat/databrowser/view/rail_pa_total/default/table?lang=en) - RAIL_PA_TYPEPAS__custom_2739445 (extracted on 17/05/2022 23:00:02 from ESTAT, last updated: 12/05/2022 23:00)*
